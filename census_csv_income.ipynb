# %%
import pandas as pd
import requests
from pprint import pprint

# %%
# Step 1: Read CSV file
csv_df = pd.read_csv('Resources/income_census_2022.csv')
print("CSV DataFrame:")
csv_df
# Out:
# CSV DataFrame:
#                                     Label (Grouping)  \
# 0   -> Nashville-Davidson--Murfreesboro--Franklin...
# 1   -> Nashville-Davidson--Murfreesboro--Franklin...
# 2                                           Estimate
# 3                                    Margin of Error
# 4   -> Nashville-Davidson--Murfreesboro--Franklin...
# 5                                           Estimate
# 6                                    Margin of Error
# 7   -> Nashville-Davidson--Murfreesboro--Franklin...
# 8                                           Estimate
# 9                                    Margin of Error
#
#    HOUSEHOLD INCOME BY RACE AND HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ...

# %%
df_dropped = csv_df.drop(['HOUSEHOLD INCOME BY RACE AND HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER','FAMILIES','FAMILY INCOME BY NUMBER OF EARNERS'], axis=1)

df_dropped
# Out:
#                                     Label (Grouping)  \
# 0   -> Nashville-Davidson--Murfreesboro--Franklin...
# 1   -> Nashville-Davidson--Murfreesboro--Franklin...
# 2                                           Estimate
# 3                                    Margin of Error
# 4   -> Nashville-Davidson--Murfreesboro--Franklin...
# 5                                           Estimate
# 6                                    Margin of Error
# 7   -> Nashville-Davidson--Murfreesboro--Franklin...
# 8                                           Estimate
# 9                                    Margin of Error
#
#   HOUSEHOLD INCOME BY RACE AND HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER!!Households  \
# 0                                                NaN
# 1                                                NaN
# 2                                            831,347
# 3                                             ±5,522
# 4                                                NaN
# ...

# %%
df_dropped = df_dropped.drop([0, 1, 2, 3, 4, 5, 6, 7, 9])
print("\nDataFrame after dropping rows with index 1 and 3:")

df_dropped
# Out:
# DataFrame after dropping rows with index 1 and 3:
#    Label (Grouping)  \
# 8          Estimate
#
#   HOUSEHOLD INCOME BY RACE AND HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER!!Households  \
# 8                                             80,034
#
#    HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER  \
# 8                                     NaN
#
#   HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER!!15 to 24 years  \
# 8                                             45,597
#
#   HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER!!25 to 44 years  \
# 8                                             85,269
#
#   HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER!!45 to 64 years  \
# 8                                             97,309
#
#   HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER!!65 years and over  \
# 8                                             58,342
#
#    FAMILY INCOME BY FAMILY SIZE  \
# 8                           NaN
#
#   FAMILY INCOME BY FAMILY SIZE!!2-person families  \
# 8                                          85,853
# ...

# %%
  

df_dropped = df_dropped.drop(['HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER','FAMILY INCOME BY FAMILY SIZE','NONFAMILY HOUSEHOLDS'], axis=1)

df_dropped
# Out:
#    Label (Grouping)  \
# 8          Estimate
#
#   HOUSEHOLD INCOME BY RACE AND HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER!!Households  \
# 8                                             80,034
#
#   HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER!!15 to 24 years  \
# 8                                             45,597
#
#   HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER!!25 to 44 years  \
# 8                                             85,269
#
#   HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER!!45 to 64 years  \
# 8                                             97,309
#
#   HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER!!65 years and over  \
# 8                                             58,342
#
#   FAMILY INCOME BY FAMILY SIZE!!2-person families  \
# 8                                          85,853
#
#   FAMILY INCOME BY FAMILY SIZE!!3-person families  \
# 8                                         105,253
#
#   FAMILY INCOME BY FAMILY SIZE!!4-person families  \
# 8                                         116,585
# ...
